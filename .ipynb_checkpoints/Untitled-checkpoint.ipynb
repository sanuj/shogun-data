# %%
% matplotlib inline
import matplotlib.pyplot as plt
from modshogun import RealFeatures, CSVFile

train_feat = RealFeatures(CSVFile('toy/regression_1d_linear_features_train.dat')).get_feature_matrix()
train_label = RealFeatures(CSVFile('toy/regression_1d_linear_labels_train.dat')).get_feature_matrix()
plt.plot(train_feat[0], train_label[0], 'r.')

# %%
train_feat = RealFeatures(CSVFile('toy/regression_1d_linear_features_test.dat')).get_feature_matrix()
train_label = RealFeatures(CSVFile('toy/regression_1d_linear_labels_test.dat')).get_feature_matrix()
plt.plot(train_feat[0], train_label[0], 'b.')

# %%
train_feat = RealFeatures(CSVFile('toy/regression_1d_sinc_features_train.dat')).get_feature_matrix()
train_label = RealFeatures(CSVFile('toy/regression_1d_sinc_labels_train.dat')).get_feature_matrix()
plt.plot(train_feat[0], train_label[0], 'r.')

# %%
train_feat = RealFeatures(CSVFile('toy/regression_1d_sinc_features_test.dat')).get_feature_matrix()
train_label = RealFeatures(CSVFile('toy/regression_1d_sinc_labels_test.dat')).get_feature_matrix()
plt.plot(train_feat[0], train_label[0], 'b.')
